# %% [markdown]
# <a href="https://colab.research.google.com/github/loujjj/Machine-Learning/blob/main/Probability_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w1 = 1/(2*np.pi)
w2 = 1
w3 = 2*np.pi
x = np.linspace(0, 10, 500)

# %%
# Define the functions to plot

def f1(x):
    return 1 + np.exp(-2*x) - 2*np.exp(-x)*np.cos(w1*x)

def f2(x):
    return 1 + np.exp(-2*x) - 2*np.exp(-x)*np.cos(w2*x)

def f3(x):
    return 1 + np.exp(-2*x) - 2*np.exp(-x)*np.cos(w3*x)

# %%
plt.xlabel('Time')
plt.ylabel('Probability')
plt.title('Probability for the first excited state  for t>=0 ')

plt.plot(x, f1(x), label='w = 1/2*pi')
plt.plot(x, f2(x), label='w = 1')
plt.plot(x, f3(x), label='w = 2*pi')

plt.legend()

plt.show()
